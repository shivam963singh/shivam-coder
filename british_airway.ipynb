# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
web = requests.get('https://www.airlinequality.com/airline-reviews/british-airways/?sortby=post_date%3ADesc&pagesize=100')

# %%
web.status_code
# Out:
# 200

# %%
web.content # Check the status code of the response
# Check the content of the response
soup = BeautifulSoup(web.content, 'html.parser')
soup.prettify() # pretty print the soup object
# Out:
# '<!DOCTYPE html>\n<!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7 lt-ie10" lang="en-GB"> <![endif]-->\n<!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8 lt-ie10" lang="en-GB"> <![endif]-->\n<!--[if IE 8]>    <html class="no-js lt-ie9 lt-ie10" lang="en-GB"> <![endif]-->\n<!--[if IE 9]>    <html class="no-js lt-ie10" lang="en-GB"> <![endif]-->\n<!--[if gt IE 8]><!-->\n<html lang="en-GB">\n <!--<![endif]-->\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   British Airways Customer Reviews - SKYTRAX\n  </title>\n  <!-- Google Chrome Frame for IE -->\n  <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>\n  <!-- mobile meta -->\n  <meta content="True" name="HandheldFriendly"/>\n  <meta content="320" name="MobileOptimized"/>\n  <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport">\n   <!-- icons & favicons -->\n   <link href="https://www.airlinequality.com/wp-content/themes/airlinequality2014ne
# ...

# %%
obj = soup.find_all('div',class_="review-stats")
print(obj[0].text) # print the first object in the list
print(obj[1].text) # print the second object in the list
print(obj[2].text) # print the third object in the list 
print(len(obj)) # print the length of the list
# Out:
# AircraftBoeing 777
# Type Of TravellerFamily Leisure
# Seat TypePremium Economy
# RouteToronto to London
# Date FlownJuly 2025
#
# Seat Comfort
# 12345
#
#
# Cabin Staff Service
# 12345
#
#
# Food & Beverages
# 12345
#
#
# Inflight Entertainment
# 12345
#
#
# Ground Service
# 12345
#
#
# Value For Money
# 12345
#
# Recommendedno
#
#
#
# AircraftA320
# Type Of TravellerSolo Leisure
# Seat TypeEconomy Class
# RouteLondon Heathrow to Inverness
# Date FlownJuly 2025
#
# Seat Comfort
# 12345
#
#
# Cabin Staff Service
# 12345
#
#
# Food & Beverages
# 12345
#
#
# Ground Service
# 12345
#
#
# Value For Money
# 12345
#
# Recommendedno
#
#
#
# AircraftA320
# Type Of TravellerSolo Leisure
# Seat TypeEconomy Class
# RouteDublin to London
# Date FlownAugust 2025
#
# Seat Comfort
# 12345
#
#
# Cabin Staff Service
# 12345
#
#
# Ground Service
# 12345
#
#
# Value For Money
# 12345
#
# RecommendedyesClose
#
# 100

# %%
containers = soup.find_all('div', class_='col-content')
# print(containers) # Check the number of containers found

# %%
# l1 = containers.find('article', class_='comp comp_reviews-airline querylist position-content')
for i in l1:
    # print(i) # Check the number of containers found
    # print(i.prettify()) # pretty print the soup object
# Out:
#   Cell In[7], line 4
#     # print(i.prettify()) # pretty print the soup object
#                                                         ^
# SyntaxError: incomplete input

# %%
menu = soup.find_all('div', class_='tabs-content') # Find all divs with class 'tabs-content'
# print(menu) # Print the menu object to see its content
if menu:  # Check if the menu list is not empty
	header = menu[0].find('h2') # Find the first h2 tag within the first menu object
	print(header) # Print the header object to see its content
else:
	print("No 'tabs-content' div found")
# Out:
# No 'tabs-content' div found
